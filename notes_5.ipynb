# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.interactive(True)
plt.ion()
matplotlib.is_interactive()
# Out:
# True

# %%
# Plotting stock data to 
data_a = pd.read_csv('resources/stocks.csv')
data_a
# Out:
#          Date        AAPL        ADBE         CVX        GOOG         IBM  \
# 0    3-Jan-07   11.107141   38.869999   50.777351  251.001007   79.242500
# 1    1-Feb-07   10.962033   39.250000   48.082939  224.949951   74.503204
# 2    1-Mar-07   12.037377   41.700001   51.900383  229.309311   75.561348
# 3    2-Apr-07   12.930043   41.560001   54.588032  235.925919   81.934280
# 4    1-May-07   15.701322   44.060001   57.598267  249.204208   85.786057
# ..        ...         ...         ...         ...         ...         ...
# 116  1-Sep-16  111.987015  108.540001  100.933739  804.059998  156.186905
# 117  3-Oct-16  112.472404  107.510002  102.728424  809.900024  151.113403
# 118  1-Nov-16  110.042900  102.809998  110.502274  775.880005  160.947403
# 119  1-Dec-16  115.320023  102.949997  116.584061  792.450012  164.687836
# 120  3-Jan-17  121.104935  113.820000  110.759811  823.830017  174.420883
#
#           MDLZ       MSFT        NFLX       ORCL       SBUX
# ...

# %%
data_a['Date'] = pd.to_datetime(data_a['Date'])
data_a.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
fig_a = plt.figure(figsize=(10,10))
ax_a = fig_a.add_axes([0,0,1,1])
ax_b = fig_a.add_axes([0.05,0.65,0.5,0.3])

ax_a.plot(data_a['Date'], data_a['AAPL'], color = 'g')
ax_b.plot(data_a['Date'], data_a['IBM'], color = 'r')
ax_a.set_title('Apple vs IBM')
# Way to plot several stock data frames in a plot
# Out:
# Text(0.5, 1.0, 'Apple vs IBM')

# %%
fig_b = plt.figure(figsize=(10,10))
fig_b.suptitle('Stock price comparison 2007-2017')
ax_c = fig_b.add_subplot(221)
ax_c.set_title('Microsoft')
ax_c.plot(data_a['Date'], data_a['MSFT'], color = 'g')

ax_c = fig_b.add_subplot(222)
ax_c.set_title('Google')
ax_c.plot(data_a['Date'], data_a['GOOG'], color = 'r')

ax_c = fig_b.add_subplot(223)
ax_c.set_title('Starbucks')
ax_c.plot(data_a['Date'], data_a['SBUX'], color = 'b')

ax_c = fig_b.add_subplot(224)
ax_c.set_title('Chevron')
ax_c.plot(data_a['Date'], data_a['CVX'], color = 'y')
fig_b
